# %%
# %pip install "unstructured[all-docs]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# ERROR: Could not find a version that satisfies the requirement poppler (from versions: none)
# ERROR: No matching distribution found for poppler
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'

# %%
# %pip install python-magic
#pandoc tesseract

# %%
import os

# %%
os.chdir(r"C:\Users\Steven\Documents\Python\super-search")

# %%
from unstructured.partition.auto import partition

elements = partition(filename="./data/tests/fake-email.eml")
print("\n\n".join([str(el) for el in elements]))
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[16], line 3
#       1 from unstructured.partition.auto import partition
# ----> 3 elements = partition(filename="./data/tests/fake-email.eml")
#       4 print("\n\n".join([str(el) for el in elements]))
#
# ...

# %%
import unstructured.documents

# %%
unstructured.documents.__doc__
